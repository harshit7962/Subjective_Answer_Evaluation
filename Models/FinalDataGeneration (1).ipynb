# %%
import pandas as pd
from datasets import load_dataset
from fastpunct import FastPunct
import re
from keybert import KeyBERT
from nltk.tag import pos_tag
from nltk.corpus import wordnet
from nltk.tokenize import word_tokenize
import nltk
import spacy
import numpy as np
import itertools
import yake
import matplotlib.pyplot as plt
import math  
import sklearn.metrics
from sentence_transformers import SentenceTransformer
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from numpy.linalg import norm
from nltk.tokenize import sent_tokenize
from sentence_transformers import SentenceTransformer
from sentence_transformers import CrossEncoder
import torch
from transformers import T5Tokenizer, T5ForConditionalGeneration, T5Config
import spacy_transformers
from transformers import AutoTokenizer, AutoModelForTokenClassification
import en_core_web_trf
nltk.download('words')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
from nltk.tree import *
from nltk import word_tokenize, pos_tag, ne_chunk
from transformers import pipeline
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Raghav\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Raghav\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Raghav\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\Raghav\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!

# %%
# Importing the dataset
df = pd.read_excel("C:/Users/Raghav/Downloads/FinalDatasetQA.xlsx")
df
# Out:
#      S. No                                           Question  \
# 0        1  What is an Operating Systems?Why do we need an...
# 1        2  Explain different types of tasks done by OS an...
# 2        3          Give the view of OS as a Resource Manager
# 3        4        Give the view of OS as an extended machine.
# 4        5                        What is Deadlock Avoidance?
# ..     ...                                                ...
# 185    186  Explain about different types of integrity con...
# 186    187  Explain different types of database users and ...
# 187    188                                 Explain about RAID
# 188    189  Discuss the failures that can occur with loss ...
# 189    190  Explain about different types of locks? (DOMAI...
#
#                                           Model Answer  \
# 0    An operating system (OS) is a collection of so...
# 1    Operating System services and facilites can be...
# 2    The concept of an operating system as providin...
# 3    The operating Systems perform two basically un...
# 4    Deadlock avoidance is a set of techniques used...
# ..                                                 ...
# 185  Integrity constraints are used to ensure that ...
# 186  Types of Database Users:  1. Application Users...
# 187  RAID (Redundant Array of Independent Disks) is...
# 188  Non-volatile storage is an essential component...
# 189  1. Shared Locks (S Locks): A shared lock is a ...
#
#                                            User Answer  Actual Score (0-10)
# 0    An operating system is a program that acts as ...                  4.0
# 1    Following are the services provided by an oper...                  4.0
# 2    From a high-level perspective, an operating sy...                  6.0
# 3    From another perspective, an operating system ...                  4.0
# 4    Deadlock avoidance is a technique used in oper...                  3.0
# ..                                                 ...                  ...
# 185  Integrity constraints are a set of rules. It i...                  7.5
# 186  Types of Database Users: 1. End-User: End-user...                  8.0
# 187  RAID (Redundant Array of Independent Disks) is...                  6.5
# 188  The basic scheme is to dump the entire content...                  0.0
# 189  1. Padlocks: Padlocks are one of the most comm...                  0.5
#
# [190 rows x 5 columns]

# %%
R_patterns = [
   (r'won\'t', 'will not'),
   (r'can\'t', 'can not'),
   (r'(\w+)\'m', '\g<1> am'),
   (r'(\w+)\'ll', '\g<1> will'),
   (r'(\w+)\'d like to', '\g<1> would like to'),
   (r'(\w+)n\'t', '\g<1> not'),
   (r'(\w+)\'ve', '\g<1> have'),
   (r'(\w+)\'s', '\g<1> is'),
   (r'(\w+)\'re', '\g<1> are')
]

class REReplacer(object):
   def __init__(self, patterns = R_patterns):
      self.patterns = [(re.compile(regex), repl) for (regex, repl) in R_patterns]
   def replace(self, text):
      s = text
      for (pattern, repl) in self.patterns:
         s = re.sub(pattern, repl, s)
      return s

# %%
# n = len(df['User Answer'])
# # """
# # for i in range(n):
# #     print(df['User Answer'][i])
# #     df['User Answer'].apply(rep_word.replace)

# rep_word = REReplacer()

# for i in range(n):
#     print(i)
#     rep_word.replace(df['User Answer'][i])

# %%
rep_word = REReplacer()

def text_lower(x):
    return x.lower()
def corrector(x):
    return x.replace('. ', '.')

df['Model Answer'] = df['Model Answer'].apply(rep_word.replace)
df['User Answer'] = df['User Answer'].apply(rep_word.replace)

mod_ans_set = df.iloc[:, 2].values
usr_ans_set = df.iloc[:, 3].values

df['Model Answer'] = df['Model Answer'].apply(text_lower)
df['User Answer'] = df['User Answer'].apply(text_lower)

df['Model Answer'] = df['Model Answer'].apply(corrector)
df['User Answer'] = df['User Answer'].apply(corrector)

# %%
def replace_punct(x):
    pattern = "[^\w\d\+\*\-\\\=\s]"   
    repl = " "
    
    return re.sub(pattern, repl, x)

def remove_extra(text):
    return " ".join(text.strip().split())

df['Model Answer'] = df['Model Answer'].apply(replace_punct)
df['User Answer'] = df['User Answer'].apply(replace_punct)

df['Model Answer'] = df['Model Answer'].apply(remove_extra)
df['User Answer'] = df['User Answer'].apply(remove_extra)

# %%
def keybert_keywordExtractor1(text):
    kw_model = KeyBERT()
    return kw_model.extract_keywords(text, top_n = 50)
    
def keybert_keywordExtractor2(text):
    kw_model = KeyBERT()
    return kw_model.extract_keywords(text, top_n = 101)
def yake_keywordExtractor(text, language = "en", max_ngram_size = 1, deduplication_threshold = 0.9, deduplication_algo = 'seqm', windowSize = 2, numOfKeywords = 101):
    
    custom_kw_extractor = yake.KeywordExtractor(lan = language, 
                                            n = max_ngram_size, 
                                            dedupLim = deduplication_threshold, 
                                            dedupFunc = deduplication_algo, 
                                            windowsSize = windowSize, 
                                            top = numOfKeywords, 
                                            features = None)
    
    return custom_kw_extractor.extract_keywords(text)

# %%
df['keybert_keys_sentence1'] = df['Model Answer'].apply(keybert_keywordExtractor1)
df['keybert_keys_sentence2'] = df['User Answer'].apply(keybert_keywordExtractor2)

df['yake_keys_sentence1'] = df['Model Answer'].apply(yake_keywordExtractor)
df['yake_keys_sentence2'] = df['User Answer'].apply(yake_keywordExtractor)

# %%
def scoring_unit(keywords_text1, keywords_text2):
    match = 0
    total = 0
    synonym_dict = []
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          
    for token in keywords_text1:
        total += token[1]
    
    if(total == 0):
        return 10
    
    for var in keywords_text2:
        syn = wordnet.synsets(var[0])
        syn_words = [x.lemma_names() for x in syn]
        syn_words = [x for elem in syn_words for x in elem]
        syn_words.append(var[0])
        syn_words = list(set(syn_words))
        #print(syn_words)
        temp = []
        wt = word_tokenize(var[0])
        pos = pos_tag(wt)[0][1]
        for i in range(0, len(syn_words)):
            checker_wt = word_tokenize(syn_words[i])
            checker_pos = pos_tag(wt)[0][1]
            if(pos == checker_pos):
                temp.append(syn_words[i])
        synonym_dict = synonym_dict + temp
    #print(synonym_dict)
    
    for token in keywords_text1:
        syn = wordnet.synsets(token[0])
        syn_words = [x.lemma_names() for x in syn]
        syn_words = [x for elem in syn_words for x in elem]
        syn_words.append(token[0])
        syn_words = list(set(syn_words))
        if len(set(syn_words).intersection(set(synonym_dict)))!=0:
            print(token[0])
            match += token[1]
            
    return ((match*10)/total)

# %%
df['keybert_score'] = df[['keybert_keys_sentence1',
                                              'keybert_keys_sentence2']].apply(lambda x:scoring_unit(x.keybert_keys_sentence1, 
                                                                                                     x.keybert_keys_sentence2), 
                                                                                                        axis=1)
df['yake_score'] = df[['yake_keys_sentence1',
                                              'yake_keys_sentence2']].apply(lambda x:scoring_unit(x.yake_keys_sentence1, 
                                                                                                     x.yake_keys_sentence2), 
                                                                                                        axis=1)
# Out:
# os
# operating
# software
# hardware
# programs
# application
# ui
# computer
# interface
# interfaces
# program
# boot
# disk
# functionality
# services
# storage
# development
# defined
# users
# benefits
# underlying
# comprehensive
# manages
# handle
# array
# considering
# code
# network
# use
# command
# powerful
# include
# provides
# requests
# user
# directly
# make
# making
# programs
# operating
# security
# services
# program
# protection
# execution
# files
# memory
# devices
# manages
# secure
# tasks
# management
# file
# purpose
# data
# access
# users
# provides
# output
# controlled
# use
# allows
# main
# execute
# initialized
# parts
# handles
# os
# operating
# programs
# application
# processors
# processor
# program
# execution
# memory
# allocation
# manages
# manage
# devices
# resources
# allocates
# resource
# users
# manager
# controlled
# user
# memories
# decides
# view
# providing
# pieces
# given
# provides
# working
# holds
# run
# helps
# set
# operating
# computers
# storage
# files
# hardware
# systems
# application
# operations
# abstraction
# commands
# resources
# manages
# interface
# machine
# web
# complexity
# users
# functions
# messages
# dealing
# abstract
# hides
# providing
# provides
# deadlocks
# deadlock
# processes
# process
# avoidance
# allocations
# allocation
# resources
# resource
# allocated
# algorithm
# techniques
# condition
# instances
# useful
# need
# safe
# approach
# states
# state
# demanded
# used
# declare
# wait
# defined
# order
# request
# examines
# type
# number
# instance
# set
# checked
# granted
# cause
# tell
# resulting
# bankers
# banker
# deadlock
# algorithm
# allocation
# process
# money
# safety
# avoidance
# withdraw
# accounts
# checks
# account
# requirements
# tests
# resources
# check
# computer
# test
# resource
# manage
# deciding
# using
# control
# requests
# sum
# information
# maximum
# helps
# remaining
# amounts
# state
# requested
# named
# used
# deadlocks
# deadlock
# processes
# process
# recovery
# algorithms
# detection
# stall
# graph
# approaches
# detect
# detecting
# operating
# algorithm
# banker
# resource
# progress
# resources
# waiting
# need
# allocation
# rollback
# occurs
# resolving
# steps
# ensuring
# prevention
# release
# blocked
# resolve
# held
# occurring
# abort
# state
# wait
# releases
# safe
# identify
# occur
# achieved
# continue
# prevent
# used
# main
# lead
# wide
# allowing
# second
# does
# takes
# deadlocks
# deadlock
# processes
# process
# systems
# operating
# control
# recovery
# resources
# managing
# resource
# killing
# prevent
# recovers
# recovering
# consuming
# preempted
# waiting
# release
# ensure
# blocked
# need
# access
# use
# deal
# data
# occur
# results
# lead
# used
# help
# space
# deadlocks
# deadlock
# processes
# detection
# performance
# advantages
# utilization
# detecting
# disadvantages
# operating
# resources
# techniques
# recovery
# resource
# design
# corruption
# implement
# data
# loss
# use
# behavior
# requests
# state
# utilized
# advanced
# resolving
# cause
# complex
# better
# remains
# false
# terms
# deadlock
# deadlocks
# operating
# systems
# reboot
# break
# solving
# uses
# pretend
# eliminated
# picture
# ignorance
# known
# used
# detected
# function
# frequently
# stick
# head
# end
# choose
# comes
# suffer
# deadlock
# processes
# process
# resources
# resource
# preemption
# conditions
# delayed
# exclusion
# holding
# held
# waiting
# hold
# holds
# mutual
# situations
# circular
# event
# occur
# blocked
# release
# state
# situation
# released
# wait
# requesting
# completing
# needed
# requires
# time
# used
# acquire
# set
# caused
# based
# necessary
# additional
# said
# virtualization
# virtual
# operating
# applications
# storage
# application
# device
# processing
# simulates
# server
# images
# uses
# operate
# resource
# multiple
# network
# use
# create
# allowing
# allows
# run
# buffer
# memory
# look
# contains
# words
# happens
# taken
# condition
# follows
# used
# help
# hit
# paging
# pages
# memory
# storage
# page
# processes
# stored
# process
# frames
# frame
# contiguous
# secondary
# retrieve
# main
# defines
# sizes
# locations
# used
# required
# form
# divide
# divided
# equal
# brought
# processes
# scheduling
# process
# cpu
# activity
# running
# terminates
# occurs
# waiting
# loaded
# moves
# handles
# state
# taken
# ready
# fixed
# shares
# schedulers
# scheduler
# scheduling
# processes
# processing
# process
# programs
# task
# jobs
# term
# running
# job
# main
# handling
# reduces
# handles
# execute
# primary
# run
# loads
# special
# selects
# degree
# charge
# chosen
# removes
# state
# determines
# increase
# context
# processes
# switching
# process
# cpu
# switches
# execution
# mechanism
# control
# scheduler
# os
# running
# executing
# multiple
# stored
# using
# block
# store
# pcb
# state
# features
# run
# current
# loaded
# start
# point
# operating
# software
# hardware
# gui
# programs
# computer
# interface
# interfaces
# program
# boot
# graphical
# services
# cli
# storage
# defined
# users
# benefits
# manages
# handle
# array
# considering
# network
# use
# command
# include
# provides
# requests
# user
# make
# making
# os
# programs
# operating
# systems
# security
# application
# services
# program
# protection
# utility
# execution
# development
# files
# tools
# memory
# debuggers
# devices
# programmer
# manages
# secure
# tasks
# management
# core
# file
# areas
# purpose
# creating
# data
# access
# usage
# hierarchy
# users
# provides
# output
# controlled
# detection
# facilites
# allocates
# use
# allows
# main
# execute
# initialized
# accounting
# parts
# options
# assit
# editors
# various
# handles
# os
# operating
# application
# abstractions
# processors
# processor
# memory
# computer
# allocation
# manages
# manage
# devices
# resources
# allocates
# output
# resource
# manager
# controlled
# memories
# time
# input
# view
# multiple
# providing
# pieces
# given
# specific
# provides
# particular
# working
# holds
# run
# helps
# set
# operating
# storage
# files
# hardware
# programming
# devices
# program
# application
# operations
# abstraction
# photos
# commands
# manages
# interface
# machine
# write
# complexity
# functions
# dealing
# clean
# abstract
# hides
# instructions
# modify
# providing
# provides
# easier
# deadlocks
# deadlock
# processes
# process
# avoidance
# allocations
# allocation
# resources
# resource
# algorithm
# techniques
# avoid
# condition
# instances
# need
# safe
# approach
# states
# state
# demanded
# used
# declare
# wait
# defined
# order
# request
# examines
# number
# instance
# available
# set
# checked
# granted
# tell
# resulting
# bankers
# banker
# bank
# deadlock
# loan
# algorithm
# allocation
# process
# money
# safety
# withdraw
# accounts
# checks
# account
# tests
# resources
# check
# sanctioned
# test
# resource
# backing
# manage
# deciding
# predetermined
# using
# control
# sum
# simulating
# person
# maximum
# holders
# remaining
# amounts
# state
# named
# used
# deadlocks
# deadlock
# processes
# process
# recovery
# algorithms
# detection
# detect
# detecting
# operating
# algorithm
# resource
# progress
# resources
# waiting
# need
# allocation
# occurs
# resolving
# ensuring
# release
# blocked
# resolve
# held
# occurring
# state
# wait
# releases
# safe
# identify
# occur
# achieved
# continue
# prevent
# used
# main
# lead
# allowing
# second
# does
# takes
# deadlocks
# deadlock
# processes
# starvation
# process
# operating
# control
# recovery
# mechanisms
# resources
# managing
# resource
# killing
# allocated
# prevent
# recovers
# shared
# recovering
# consuming
# preempted
# waiting
# release
# ensure
# blocked
# need
# use
# deal
# data
# occur
# results
# lead
# used
# help
# space
# deadlocks
# deadlock
# processes
# detection
# performance
# advantages
# utilization
# detecting
# stability
# disadvantages
# resources
# resource
# design
# complexity
# overhead
# use
# improved
# utilized
# improving
# advanced
# resolving
# cause
# improve
# better
# remains
# deadlock
# deadlocks
# os
# operating
# algorithm
# ostrich
# systems
# correctness
# reboot
# break
# solving
# problem
# sand
# uses
# pretend
# users
# convenience
# eliminated
# picture
# ignorance
# free
# known
# used
# detected
# function
# frequently
# single
# stick
# head
# end
# different
# choose
# comes
# suffer
# deadlock
# processes
# deadlocked
# process
# resources
# resource
# preemption
# conditions
# delayed
# exclusion
# holding
# held
# waiting
# os
# hold
# holds
# task
# preempted
# mutual
# situations
# circular
# event
# occur
# blocked
# release
# state
# situation
# released
# wait
# voluntary
# requesting
# decision
# completing
# needed
# requires
# time
# used
# acquisition
# acquire
# set
# caused
# based
# necessary
# additional
# said
# currently
# virtualization
# virtual
# software
# operating
# hardware
# applications
# storage
# application
# systems
# processing
# simulates
# mainframes
# server
# images
# uses
# operate
# resource
# describes
# multiple
# benefits
# network
# use
# organizations
# create
# underlying
# allowing
# single
# allows
# run
# tlb
# buffer
# registers
# cache
# memory
# cpu
# pages
# translation
# mapping
# page
# entries
# entry
# accesses
# accessed
# table
# access
# look
# means
# smaller
# miss
# words
# contains
# reference
# main
# tags
# happens
# taken
# location
# reduce
# condition
# used
# follows
# keys
# time
# said
# desired
# frequently
# hit
# paging
# pages
# memory
# storage
# page
# processes
# stored
# process
# frames
# frame
# holes
# retrieve
# defines
# sizes
# locations
# used
# required
# form
# divide
# divided
# brought
# processes
# scheduling
# process
# execution
# cpu
# priority
# activity
# systems
# running
# allocates
# terminates
# occurs
# time
# switching
# switches
# waiting
# completes
# moves
# handles
# particular
# state
# using
# taken
# essential
# strategy
# ready
# replace
# fixed
# based
# shares
# allow
# schedulers
# scheduler
# scheduling
# processes
# processing
# processor
# cpu
# multiprogramming
# execution
# process
# performance
# programs
# queue
# swapping
# task
# software
# jobs
# term
# criteria
# running
# balanced
# job
# main
# memory
# handling
# reduces
# handles
# execute
# primary
# objective
# run
# loads
# special
# short
# selects
# accordance
# degree
# charge
# various
# swapped
# chosen
# removes
# state
# determines
# increase
# different
# types
# medium
# long
# context
# switching
# switches
# control
# running
# executing
# using
# features
# run
# current
# single
# start
# point
# processing
# speech
# language
# process
# learning
# human
# computers
# natural
# interpret
# analyze
# comprehend
# respond
# channels
# tries
# day
# work
# nlp
# processing
# speech
# language
# text
# software
# process
# learning
# feeds
# communication
# messages
# data
# sentiment
# social
# audio
# human
# automatically
# computers
# voice
# natural
# emails
# interpret
# analyze
# comprehend
# intent
# grammatical
# machine
# slang
# use
# media
# respond
# channels
# capture
# video
# message
# organizations
# tries
# comes
# differences
# manipulate
# work
# nlg
# nlp
# nlu
# language
# languages
# emotions
# understanding
# applications
# translator
# computerized
# data
# aspects
# analyze
# understand
# useful
# relations
# human
# roles
# generation
# business
# tasks
# representation
# involves
# components
# planning
# machine
# input
# essential
# converts
# natural
# realization
# spoken
# mainly
# map
# helps
# include
# problem
# written
# acts
# given
# different
# nlp
# semantic
# language
# text
# languages
# extracting
# understanding
# content
# aspects
# understand
# roles
# business
# involves
# components
# converts
# mainly
# map
# helps
# acts
# given
# nlp
# semantic
# phases
# stages
# phase
# words
# text
# meaning
# divides
# scans
# proceed
# characters
# arrangements
# check
# invokes
# helps
# applying
# concerned
# used
# converts
# depends
# syntactic
# nlp
# discourse
# semantic
# phases
# pragmatic
# lexical
# stages
# phase
# analysis
# words
# word
# deadlocks
# deadlock
# processes
# process
# avoidance
# allocations
# allocation
# resources
# resource
# algorithm
# techniques
# avoid
# condition
# instances
# need
# states
# state
# demanded
# used
# declare
# wait
# defined
# order
# request
# examines
# number
# instance
# available
# set
# checked
# granted
# tell
# resulting
# morphological
# morphemes
# linguistics
# suffix
# formalized
# prefix
# analysis
# words
# meaning
# examining
# structure
# examine
# solutions
# types
# problems
# understand
# illogical
# complex
# process
# bound
# unquantifiable
# breaks
# resolutions
# forms
# solving
# factors
# elements
# problem
# units
# basic
# involving
# eliminate
# broken
# takes
# arranged
# smallest
# matrix
# free
# help
# used
# general
# completely
# provides
# combination
# order
# possible
# known
# morphological
# morphemes
# suffix
# prefix
# analysis
# words
# meaning
# examining
# structure
# examine
# solutions
# types
# problems
# understand
# process
# bound
# breaks
# resolutions
# forms
# solving
# factors
# elements
# problem
# units
# involving
# broken
# takes
# smallest
# help
# used
# completely
# provides
# order
# known
# morphemes
# suffix
# prefix
# words
# meaning
# examining
# structure
# examine
# solutions
# types
# understand
# bound
# breaks
# resolutions
# forms
# units
# involving
# broken
# takes
# arranged
# smallest
# free
# completely
# provides
# order
# known
# morphological
# analysis
# words
# examining
# examine
# problems
# understand
# process
# breaks
# forms
# solving
# problem
# broken
# takes
# free
# help
# used
# provides
# semantic
# nlp
# ontologies
# analyzing
# knowledge
# analysis
# classification
# words
# neural
# algorithms
# phrases
# structured
# language
# learning
# sentence
# text
# sentiment
# concepts
# retrieval
# graphs
# networks
# automatically
# extract
# meaning
# information
# relationships
# deep
# models
# relevance
# approach
# using
# machine
# expressed
# improve
# results
# understand
# identifying
# underlying
# organize
# generate
# systems
# train
# involves
# tasks
# component
# technique
# essential
# ideas
# accuracy
# manner
# semantic
# nlp
# analyzing
# analysis
# words
# phrases
# structured
# language
# learning
# sentence
# text
# sentiment
# concepts
# retrieval
# extract
# meaning
# information
# relationships
# deep
# models
# approach
# using
# machine
# expressed
# results
# understand
# identifying
# organize
# generate
# systems
# train
# involves
# component
# technique
# essential
# ideas
# manner
# semantic
# nlp
# ontologies
# analyzing
# knowledge
# analysis
# classification
# words
# neural
# algorithms
# phrases
# structured
# language
# learning
# sentence
# text
# sentiment
# concepts
# retrieval
# graphs
# networks
# automatically
# extract
# meaning
# information
# relationships
# deep
# models
# relevance
# approach
# using
# machine
# expressed
# improve
# results
# understand
# identifying
# underlying
# organize
# train
# involves
# tasks
# technique
# ideas
# accuracy
# manner
# semantic
# nlp
# analysis
# words
# phrases
# language
# learning
# sentiment
# meaning
# relationships
# using
# understand
# identifying
# train
# involves
# tasks
# component
# technique
# ideas
# manner
# parsing
# syntactic
# sentences
# nlp
# speech
# analyzing
# phrases
# tagging
# extracting
# sentence
# clauses
# language
# structure
# analysis
# retrieval
# grammatically
# hierarchical
# grammatical
# dependencies
# recognition
# words
# techniques
# phrase
# dependency
# tree
# understanding
# verb
# adverb
# crucial
# organized
# information
# machines
# involves
# noun
# object
# adjective
# constituency
# identifying
# applications
# relationships
# graph
# representing
# translation
# node
# directed
# subject
# convey
# category
# meaning
# role
# parsing
# syntactic
# sentences
# nlp
# speech
# analyzing
# phrases
# tagging
# extracting
# sentence
# clauses
# language
# structure
# analysis
# retrieval
# grammatically
# hierarchical
# grammatical
# dependencies
# recognition
# words
# techniques
# phrase
# dependency
# tree
# understanding
# verb
# adverb
# crucial
# organized
# information
# machines
# involves
# noun
# object
# adjective
# constituency
# identifying
# applications
# relationships
# graph
# representing
# translation
# node
# directed
# subject
# convey
# category
# meaning
# role
# parsing
# syntactic
# sentences
# nlp
# speech
# analyzing
# phrases
# tagging
# extracting
# sentence
# language
# structure
# analysis
# retrieval
# grammatical
# words
# techniques
# phrase
# understanding
# organized
# information
# machines
# involves
# object
# identifying
# relationships
# graph
# representing
# directed
# subject
# convey
# meaning
# role
# parsing
# syntactic
# sentences
# speech
# analyzing
# phrases
# tagging
# extracting
# sentence
# clauses
# language
# structure
# analysis
# hierarchical
# grammatical
# dependencies
# words
# techniques
# phrase
# dependency
# tree
# understanding
# verb
# adverb
# organized
# information
# involves
# noun
# object
# adjective
# constituency
# identifying
# relationships
# graph
# representing
# node
# directed
# subject
# convey
# category
# meaning
# role
# pragmatic
# utterances
# speech
# dialogue
# language
# nlp
# contextual
# communicate
# communication
# contexts
# interpreting
# conveyed
# analyzing
# context
# indirect
# meanings
# cultural
# analysis
# intentions
# human
# social
# expressions
# understanding
# processing
# meaning
# speaker
# knowledge
# voice
# applications
# cues
# use
# literal
# aspects
# service
# requests
# tone
# acts
# pragmatic
# utterances
# linguistic
# speech
# conversational
# communicative
# chatbots
# dialogue
# language
# nlp
# contextual
# communicate
# communication
# contexts
# interpreting
# conveyed
# implicatures
# analyzing
# context
# indirect
# meanings
# cultural
# gestures
# analysis
# intentions
# human
# social
# expressions
# understanding
# processing
# meaning
# speaker
# knowledge
# interactions
# voice
# applications
# facial
# assistants
# customer
# cues
# use
# literal
# aspects
# promises
# service
# requests
# education
# tone
# acts
# pragmatic
# speech
# language
# contextual
# interpreting
# conveyed
# analysis
# intentions
# expressions
# understanding
# use
# aspects
# tone
# pragmatic
# chatbots
# dialogue
# nlp
# applications
# assistants
# use
# service
# discourse
# conversations
# conversation
# analyzing
# analysis
# sociology
# language
# texts
# contexts
# narratives
# narrative
# communication
# anthropology
# talk
# studies
# social
# cultural
# examining
# papers
# identities
# patterns
# meaning
# content
# relations
# represented
# studying
# relationships
# structure
# education
# words
# involves
# power
# sequencing
# use
# organization
# stories
# structures
# construct
# discourse
# linguistics
# conversations
# conversation
# analyzing
# analysis
# language
# texts
# contexts
# narratives
# narrative
# documents
# communication
# talk
# studies
# social
# cultural
# examining
# papers
# articles
# identities
# patterns
# academic
# meaning
# techniques
# content
# sentences
# relations
# genre
# represented
# genres
# studying
# relationships
# structure
# words
# groups
# involves
# power
# participants
# sequencing
# use
# organization
# stories
# structures
# achieve
# construct
# critical
# discourse
# linguistics
# conversations
# conversation
# analyzing
# analysis
# sociology
# language
# texts
# contexts
# narratives
# narrative
# communication
# anthropology
# talk
# studies
# social
# cultural
# examining
# papers
# identities
# patterns
# meaning
# techniques
# content
# sentences
# represented
# studying
# relationships
# structure
# education
# words
# involves
# power
# participants
# sequencing
# use
# organization
# stories
# structures
# achieve
# construct
# discourse
# linguistics
# conversations
# conversation
# analyzing
# analysis
# sociology
# language
# texts
# contexts
# narratives
# narrative
# documents
# communication
# anthropology
# talk
# studies
# social
# cultural
# examining
# papers
# articles
# identities
# patterns
# academic
# meaning
# techniques
# content
# sentences
# relations
# genre
# represented
# genres
# studying
# relationships
# structure
# education
# words
# groups
# involves
# power
# participants
# sequencing
# use
# organization
# stories
# structures
# achieve
# construct
# critical
# discourse
# analyzing
# analysis
# language
# contexts
# narratives
# narrative
# communication
# talk
# studies
# social
# cultural
# examining
# patterns
# meaning
# content
# sentences
# represented
# studying
# structure
# education
# words
# involves
# use
# organization
# stories
# structures
# summarization
# text
# nlp
# summary
# sentences
# phrases
# extractive
# document
# information
# learning
# generate
# generated
# extracted
# language
# abstractive
# creating
# condensed
# create
# presented
# processing
# news
# retaining
# article
# task
# machine
# method
# understand
# natural
# longer
# convey
# understands
# applications
# various
# key
# process
# original
# provide
# main
# meaning
# summarization
# text
# nlp
# summary
# sentences
# phrases
# extractive
# document
# information
# learning
# generate
# generated
# extracted
# language
# abstractive
# creating
# condensed
# create
# shorter
# presented
# processing
# news
# retaining
# article
# machine
# types
# understand
# natural
# convey
# understands
# applications
# various
# key
# process
# original
# provide
# main
# meaning
# summarization
# text
# nlp
# summary
# sentences
# phrases
# extractive
# information
# learning
# generate
# context
# structured
# automatically
# generated
# extracted
# language
# abstractive
# creating
# insights
# condensed
# create
# presented
# quick
# processing
# news
# retaining
# machine
# understand
# natural
# convey
# understands
# key
# process
# original
# provide
# main
# meaning
# summarization
# text
# nlp
# sentences
# extractive
# information
# learning
# generate
# automatically
# generated
# extracted
# language
# abstractive
# creating
# insights
# condensed
# create
# shorter
# presented
# quick
# processing
# retaining
# task
# types
# natural
# longer
# key
# process
# original
# volumes
# provide
# main
# meaning
# retrieval
# indexing
# searching
# search
# metadata
# documents
# applications
# information
# web
# keywords
# software
# data
# relevance
# ranking
# algorithms
# index
# document
# content
# using
# systems
# use
# pages
# query
# processing
# internet
# results
# collections
# retrieve
# nlp
# crawl
# questions
# answers
# list
# users
# language
# learning
# techniques
# phrases
# machine
# used
# answering
# enterprise
# accuracy
# based
# various
# context
# engines
# recommendation
# type
# products
# retrieval
# indexing
# searching
# search
# documents
# applications
# information
# web
# software
# data
# ranking
# index
# document
# using
# systems
# use
# query
# processing
# internet
# results
# collections
# retrieve
# nlp
# questions
# answers
# users
# language
# learning
# techniques
# machine
# used
# answering
# enterprise
# engines
# recommendation
# retrieval
# indexing
# searching
# search
# metadata
# documents
# applications
# information
# web
# software
# data
# relevance
# ranking
# algorithms
# index
# document
# using
# systems
# use
# query
# processing
# internet
# results
# collections
# retrieve
# nlp
# crawl
# questions
# answers
# users
# learning
# techniques
# machine
# used
# answering
# enterprise
# accuracy
# based
# engines
# recommendation
# type
# sentiment
# nlp
# analyzing
# analysis
# attitudes
# phrases
# analyze
# marketing
# text
# words
# monitoring
# classify
# applications
# data
# service
# language
# processing
# social
# positive
# neutral
# research
# tone
# opinion
# opinions
# customer
# feedback
# automatically
# learning
# determine
# negative
# use
# expressed
# information
# media
# various
# reputation
# technique
# identify
# sentiment
# nlp
# emotions
# subjective
# analyzing
# analysis
# attitudes
# analyze
# text
# words
# monitoring
# classify
# applications
# data
# service
# language
# processing
# social
# positive
# neutral
# research
# tone
# opinion
# opinions
# customer
# feedback
# extract
# automatically
# learning
# document
# determine
# negative
# use
# expressed
# information
# media
# various
# reputation
# technique
# identify
# sentiment
# subjective
# analyzing
# analysis
# attitudes
# analyze
# text
# adjectives
# algorithms
# words
# datasets
# monitoring
# data
# service
# language
# processing
# social
# positive
# neutral
# research
# tone
# opinion
# opinions
# extract
# automatically
# learning
# adverbs
# determine
# negative
# context
# use
# expressed
# information
# media
# reputation
# identify
# sentiment
# nlp
# subjective
# analyzing
# analysis
# attitudes
# analyze
# text
# words
# monitoring
# classify
# data
# service
# language
# processing
# social
# positive
# neutral
# tone
# opinion
# opinions
# customer
# feedback
# extract
# automatically
# learning
# document
# determine
# negative
# context
# use
# expressed
# information
# media
# various
# reputation
# technique
# identify
# answering
# software
# text
# questions
# applications
# systems
# assistants
# corpus
# answers
# data
# service
# processing
# learning
# programs
# nlp
# tasks
# language
# customer
# automatically
# search
# machine
# topic
# domain
# research
# trained
# asked
# learn
# virtual
# example
# improving
# users
# types
# qa
# answering
# software
# questions
# applications
# systems
# assistants
# corpus
# answers
# data
# service
# processing
# learning
# programs
# education
# nlp
# tasks
# language
# customer
# search
# machine
# topic
# domain
# research
# trained
# asked
# learn
# example
# law
# medicine
# improving
# users
# types
# qa
# answering
# software
# text
# questions
# systems
# corpus
# answers
# data
# service
# processing
# learning
# programs
# tasks
# articles
# unstructured
# wikipedia
# language
# automatically
# search
# machine
# computer
# topic
# domain
# research
# trained
# asked
# learn
# example
# law
# finance
# optimized
# medicine
# improving
# types
# qa
# answering
# software
# text
# questions
# applications
# systems
# corpus
# answers
# data
# service
# processing
# learning
# unstructured
# wikipedia
# language
# automatically
# search
# machine
# computer
# topic
# domain
# research
# trained
# asked
# learn
# example
# law
# finance
# improving
# types
# deadlock
# deadlocks
# os
# operating
# algorithm
# ostrich
# systems
# method
# methods
# correctness
# reboot
# break
# solving
# problem
# sand
# uses
# people
# pretend
# users
# convenience
# eliminated
# picture
# ignorance
# widely
# free
# known
# according
# used
# detected
# function
# varies
# frequently
# single
# stick
# head
# end
# choose
# comes
# suffer
# deadlock
# processes
# deadlocked
# process
# resources
# resource
# preemption
# conditions
# delayed
# exclusion
# holding
# held
# waiting
# os
# hold
# holds
# task
# preempted
# mutual
# situations
# circular
# event
# blocked
# release
# state
# situation
# released
# wait
# voluntary
# requesting
# decision
# completing
# needed
# requires
# time
# used
# acquisition
# acquire
# set
# caused
# based
# additional
# said
# currently
# virtualization
# virtual
# os
# software
# operating
# hardware
# technology
# applications
# storage
# application
# device
# systems
# processing
# mainframes
# server
# images
# economies
# uses
# operate
# creation
# resource
# describes
# multiple
# efficiencies
# wasting
# power
# network
# use
# organizations
# create
# actual
# scale
# expensive
# greater
# allowing
# single
# allows
# run
# iot
# protocols
# sensors
# design
# hardware
# physical
# logical
# devices
# components
# data
# processes
# internet
# functionality
# layout
# communicates
# algorithms
# structured
# connections
# applications
# interacts
# software
# determines
# placement
# wiring
# things
# essential
# interactions
# environment
# analyzed
# efficiency
# proper
# functioning
# refers
# responds
# processed
# organized
# overall
# critical
# different
# includes
# collected
# actual
# make
# way
# collects
# including
# govern
# data
# dacs
# digital
# daq
# acquisition
# sensors
# analog
# adcs
# monitoring
# hardware
# software
# computer
# signals
# purposes
# collecting
# device
# information
# systems
# purpose
# analysis
# devices
# collection
# converters
# process
# components
# physical
# amplifiers
# gather
# control
# analyzed
# using
# processed
# sources
# environment
# used
# manage
# flash
# interrupt
# memory
# timers
# program
# powered
# power
# operate
# making
# come
# m2m
# devices
# communicate
# data
# communication
# automated
# networks
# use
# process
# used
# key
# responses
# solution
# includes
# following
# include
# iot
# monitoring
# devices
# device
# monitor
# hospital
# connect
# sleep
# patterns
# range
# approach
# oriented
# rate
# based
# broader
# addition
# taken
# various
# advanced
# directly
# iot
# value
# chain
# patterns
# driven
# processing
# identify
# devices
# filtering
# trends
# creating
# generated
# processed
# stages
# stage
# different
# acquired
# iot
# architecture
# interoperability
# encryption
# requirements
# authentication
# security
# hardware
# infrastructure
# scalable
# devices
# scalability
# secure
# reliability
# design
# services
# modular
# upgrades
# applications
# interfaces
# objectives
# customization
# modularity
# features
# ensuring
# reliable
# needs
# systems
# communicate
# components
# seamless
# capable
# integration
# upgraded
# consideration
# compromising
# innovative
# effectiveness
# software
# flexible
# creation
# performance
# range
# needed
# expensive
# disruptions
# existing
# data
# designed
# leveraging
# iot
# sensors
# layer
# layers
# middleware
# internet
# technologies
# devices
# data
# network
# infrastructure
# networks
# services
# processing
# perception
# applications
# things
# communication
# components
# application
# smart
# analysis
# transmitted
# learning
# meters
# gather
# message
# provides
# devices
# device
# data
# processing
# functions
# features
# function
# control
# needs
# analyzed
# reduce
# manage
# reducing
# edge
# rfid
# iot
# wireless
# bluetooth
# zigbee
# protocol
# technologies
# devices
# protocols
# sensors
# technology
# sensor
# internet
# tags
# radio
# wsns
# applications
# uses
# automation
# communication
# objects
# frequency
# network
# things
# energy
# ble
# field
# identification
# connectivity
# waves
# use
# smart
# industrial
# identify
# range
# iot
# data
# sensors
# information
# sensing
# cloud
# internet
# aggregation
# context
# processing
# enrichment
# filtering
# things
# statistical
# process
# analysis
# flow
# humidity
# temperature
# identifying
# collecting
# location
# added
# collected
# step
# using
# techniques
# steps
# processed
# adding
# platform
# stored
# world
# motion
# pressure
# based
# iot
# cloud
# patterns
# internet
# pattern
# data
# network
# sensors
# information
# processes
# sends
# platforms
# platform
# edge
# situations
# exchange
# things
# analysis
# used
# processed
# control
# analyzed
# based
# direct
# send
# collects
# sent
# central
# involvement
# m2m
# iot
# verizon
# telekom
# mobile
# cellular
# market
# network
# internet
# vodafone
# technologies
# devices
# device
# demand
# automation
# companies
# services
# connectivity
# data
# industrial
# machine
# analytics
# application
# rate
# cars
# management
# platforms
# advancements
# growth
# healthcare
# range
# driven
# smart
# according
# china
# use
# research
# cities
# deutsche
# rising
# enablement
# key
# increasing
# connected
# things
# growing
# coming
# time
# real
# continue
# iot
# sensors
# data
# automation
# technology
# devices
# internet
# applications
# energy
# smart
# usage
# things
# automate
# utilization
# lighting
# using
# industrial
# traffic
# optimize
# processes
# logistics
# manufacturing
# cities
# safety
# create
# used
# life
# reduce
# resource
# city
# flow
# network
# networks
# lan
# lans
# wlans
# wan
# wlan
# computers
# internet
# wans
# wireless
# technology
# devices
# computer
# area
# buildings
# types
# servers
# geographical
# offices
# uses
# campus
# secure
# connect
# airports
# printers
# access
# wi
# centers
# connected
# larger
# wide
# typically
# confined
# large
# local
# multiple
# type
# p2p
# servers
# peer
# server
# network
# bittorrent
# networks
# centralized
# decentralized
# clients
# devices
# services
# backup
# sharing
# resources
# data
# maintain
# share
# device
# failures
# computer
# communicate
# file
# control
# manages
# expensive
# central
# failure
# used
# point
# acts
# need
# based
# act
# multiplexing
# transmitting
# transmit
# duplex
# simplex
# transmission
# modes
# transmitted
# signals
# mode
# signal
# broadcast
# communicating
# network
# data
# bandwidth
# television
# receiver
# broadcaster
# telephone
# simultaneously
# networks
# talkie
# speak
# tdm
# computer
# transfer
# devices
# speed
# direction
# sender
# division
# walkie
# turns
# advanced
# specific
# directions
# example
# half
# limited
# requirements
# viewer
# needs
# single
# use
# share
# routers
# bridges
# networking
# hubs
# lans
# network
# ports
# switches
# traffic
# networks
# devices
# internet
# port
# communication
# data
# transmitted
# device
# filter
# computer
# connect
# receive
# direct
# purpose
# used
# sections
# received
# different
# ability
# serves
# flow
# control
# receiver
# network
# sender
# networks
# data
# prevent
# devices
# monitor
# mechanism
# device
# implemented
# manage
# use
# computer
# types
# purpose
# used
# performance
# loss
# points
# type
# reduced
# result
# ensure
# overwhelming
# control
# receiver
# mechanism
# networking
# ensure
# uses
# data
# networks
# purpose
# process
# match
# sender
# computer
# issues
# used
# gateways
# gateway
# networking
# firewalls
# traffic
# network
# qos
# protocols
# lans
# networks
# lan
# security
# internet
# bandwidth
# protocol
# monitoring
# intrusion
# hardware
# communication
# communicate
# software
# connects
# management
# systems
# detection
# devices
# computer
# threats
# functions
# connecting
# purpose
# data
# translator
# device
# translation
# service
# schemes
# features
# addressing
# connect
# use
# implemented
# area
# prevention
# addresses
# external
# used
# quality
# multicasting
# anycasting
# broadcast
# broadcasting
# unicasting
# communication
# packet
# networking
# network
# device
# devices
# sends
# method
# methods
# computer
# share
# single
# types
# different
# used
# point
# address
# sent
# dhcp
# ip
# addresses
# subnet
# dns
# network
# assignment
# protocol
# networks
# devices
# address
# parameters
# assigns
# assign
# server
# host
# gateway
# configuration
# assigned
# device
# requests
# configure
# manual
# mask
# uses
# dynamic
# pool
# conflicts
# provides
# default
# automatically
# communicate
# administrators
# especially
# request
# stands
# prone
# large
# manage
# receives
# time
# following
# helps
# need
# track
# reduce
# eliminates
# keeps
# piggybacking
# term
# marketing
# riding
# transporting
# advertising
# transportation
# unauthorized
# meanings
# means
# convenience
# networking
# effective
# login
# network
# password
# goods
# purpose
# secure
# gaining
# credentials
# users
# context
# access
# taking
# act
# efficient
# company
# user
# customer
# contexts
# refer
# resources
# achieve
# using
# audience
# involves
# train
# efforts
# general
# information
# shares
# nic
# nics
# interface
# network
# hardware
# computers
# card
# cards
# speeds
# computer
# devices
# protocols
# transmission
# device
# connection
# data
# fiber
# physical
# connecting
# desktop
# switches
# types
# involves
# transfer
# laptop
# servers
# connect
# variety
# provides
# flow
# providing
# receive
# firewalls
# firewall
# subnet
# subnets
# subnetworks
# mask
# masks
# ip
# networking
# 255
# 192
# notation
# network
# security
# addresses
# bits
# bitwise
# numbers
# attacks
# broadcast
# divisions
# formats
# portions
# number
# 32
# 168
# portion
# cidr
# divide
# computer
# address
# dividing
# decimal
# indicates
# communication
# identifies
# larger
# reveals
# smaller
# sets
# represents
# operation
# host
# device
# representing
# uses
# example
# traffic
# limiting
# bit
# dns
# domains
# resolver
# domain
# servers
# ip
# resolve
# internet
# addresses
# naming
# web
# isp
# database
# queries
# net
# distributed
# records
# contacts
# corresponding
# root
# websites
# hierarchical
# information
# service
# com
# address
# names
# infrastructure
# provider
# process
# caching
# performance
# network
# application
# org
# browser
# traffic
# sends
# stands
# correspond
# maintaining
# users
# level
# using
# map
# use
# localhost
# local
# hostname
# ip
# loopback
# 127
# connecting
# networking
# term
# web
# connects
# useful
# network
# ipv4
# testing
# address
# computer
# using
# application
# test
# interface
# used
# running
# applications
# reserved
# troubleshooting
# program
# points
# run
# refer
# encapsulation
# protocols
# protocol
# processing
# layers
# processes
# networking
# data
# layer
# process
# stack
# headers
# device
# network
# flow
# functions
# header
# corresponding
# transmitted
# involves
# removes
# trailer
# trailers
# performed
# perform
# passes
# pipelining
# pipeline
# pipelined
# processing
# throughput
# concurrently
# processors
# architecture
# networking
# delays
# performance
# simultaneously
# segments
# execution
# faster
# efficiency
# processed
# operations
# network
# stages
# segment
# memory
# transmission
# operation
# transmitting
# overlapped
# computer
# overlapping
# decoding
# data
# fetching
# optimization
# stage
# design
# instruction
# technique
# multiple
# performing
# operate
# smaller
# powerful
# requires
# errors
# increased
# overall
# antennas
# signal
# cable
# transmit
# attenuation
# connectivity
# amplifier
# network
# networking
# amplifying
# amplify
# booster
# repeater
# improve
# reducing
# decrease
# cat
# directional
# boost
# problem
# performance
# reduce
# focus
# upgrading
# loss
# help
# using
# strength
# solution
# root
# problems
# direction
# helping
# resulting
# fix
# walls
# fixing
# specific
# example
# objects
# quality
# cause
# issues
# basements
# ways
# used
# vpn
# securely
# network
# private
# connection
# technology
# connect
# virtual
# connected
# users
# internet
# user
# individuals
# provide
# workgroup
# centralized
# networking
# network
# networks
# domain
# management
# computers
# security
# manages
# accounts
# shared
# server
# resources
# managing
# resource
# models
# access
# computer
# model
# authenticating
# users
# account
# sharing
# managed
# files
# share
# user
# required
# controller
# types
# using
# use
# used
# enforcing
# log
# networking
# network
# operating
# web
# permissions
# allows
# connected
# messages
# forwarding
# transmitting
# packets
# packet
# switching
# network
# transmitted
# nodes
# forward
# forwards
# message
# destination
# waits
# node
# control
# techniques
# reliable
# reads
# faster
# forwarded
# intermediate
# technique
# integrity
# waiting
# stored
# slow
# reach
# main
# confirmation
# method
# store
# separately
# small
# soon
# verify
# path
# need
# detected
# tcp
# handshake
# syn
# ack
# steps
# request
# involves
# step
# proxy
# bandwidth
# servers
# server
# internet
# traffic
# security
# gateway
# ip
# benefits
# privacy
# requests
# performance
# cache
# filter
# resources
# resource
# clients
# network
# websites
# client
# computer
# networks
# intermediary
# information
# accessed
# access
# restrict
# prevent
# management
# employee
# use
# control
# website
# request
# need
# help
# blockchain
# bitcoin
# cryptocurrencies
# technology
# decentralized
# ledger
# chain
# transactions
# data
# secure
# database
# computers
# digital
# blocks
# finance
# distributed
# block
# network
# information
# management
# applications
# healthcare
# stored
# server
# node
# nodes
# chronological
# use
# features
# industries
# record
# creating
# nature
# previous
# ensure
# blockchains
# blockchain
# consortium
# ethereum
# organizations
# decentralized
# organization
# bitcoin
# types
# chain
# networks
# business
# internal
# authority
# network
# private
# public
# transactions
# parties
# type
# fabric
# r3
# provide
# hyperledger
# main
# examples
# corda
# controlled
# operations
# blockchains
# blockchain
# transactions
# database
# records
# transaction
# data
# metadata
# cryptographic
# cryptocurrency
# record
# blocks
# digital
# information
# types
# hash
# objects
# assets
# chain
# block
# contracts
# transfer
# sequential
# tamper
# secure
# verifying
# timestamp
# transferred
# store
# decentralized
# account
# value
# validated
# contract
# terms
# unique
# exchange
# process
# nonce
# proof
# reliable
# network
# enforcing
# previous
# smart
# typically
# present
# self
# transparent
# exchanged
# blockchain
# cryptographic
# decentralized
# transactions
# immutability
# ledger
# technology
# security
# immutable
# chain
# features
# transparency
# efficiency
# hash
# transaction
# data
# block
# authority
# finance
# assets
# tamper
# permanent
# network
# smart
# management
# secured
# eliminating
# applications
# uses
# trace
# techniques
# stored
# efficient
# distributed
# information
# enforcing
# meaning
# contracts
# transfer
# history
# healthcare
# nodes
# self
# manage
# automatically
# copy
# blockchain
# data
# records
# technology
# stored
# transactions
# types
# information
# security
# type
# network
# secure
# protection
# use
# cases
# store
# using
# control
# requirements
# wide
# limit
# processed
# share
# used
# example
# level
# subject
# provides
# greater
# range
# blockchain
# decentralized
# technology
# ledger
# cryptographic
# transparency
# security
# chain
# centralized
# immutability
# efficiency
# immutable
# transactions
# block
# transparent
# smart
# secure
# authority
# organizations
# transaction
# data
# management
# networks
# systems
# network
# attacks
# benefits
# hash
# uses
# tamper
# assets
# secured
# trace
# permanent
# eliminating
# efficient
# techniques
# contracts
# double
# spending
# cryptocurrency
# spend
# transactions
# transaction
# spent
# process
# duplicate
# duplicated
# digital
# assets
# uses
# asset
# effectively
# reverse
# decentralized
# daos
# blockchain
# organization
# governance
# organizations
# centralized
# governing
# organizing
# authority
# dao
# systems
# governed
# algorithms
# democratic
# platform
# manage
# govern
# autonomous
# fund
# based
# controlled
# features
# finance
# operations
# investment
# participation
# decisions
# social
# network
# processes
# criteria
# operates
# enforced
# vote
# automatically
# rules
# meaning
# allowing
# members
# operate
# computer
# coinbase
# transactions
# transaction
# coin
# coins
# blockchain
# reward
# spending
# miner
# generation
# balance
# spent
# chain
# newly
# creates
# fees
# protocol
# new
# output
# subsequent
# collect
# fee
# network
# input
# supply
# sum
# previous
# paid
# specifies
# approaches
# predetermined
# include
# specify
# created
# sender
# key
# decreases
# included
# typical
# public
# adding
# maximum
# confirmed
# block
# blockchain
# scalability
# decentralization
# technology
# governance
# mining
# immutability
# standardization
# limitations
# advantages
# security
# systems
# networks
# transactions
# limitation
# computationally
# sustainable
# network
# disputes
# consumption
# scale
# power
# energy
# transparency
# carbon
# applications
# nodes
# footprint
# widespread
# transaction
# expensive
# benefits
# limit
# issues
# increase
# adoption
# achieve
# large
# slow
# challenging
# rewards
# cases
# lead
# blockchain
# pow
# miners
# stake
# cryptocurrency
# miner
# pos
# computing
# differences
# difference
# work
# consensus
# mathematical
# networks
# blocks
# transactions
# network
# proof
# gaining
# control
# transaction
# required
# processes
# logistics
# datasets
# data
# mining
# applications
# forecasting
# marketing
# churn
# uses
# segmentation
# analysis
# business
# personalized
# learning
# basket
# patterns
# customer
# recommendation
# trends
# trend
# healthcare
# maintenance
# predictive
# inventory
# optimize
# fraud
# student
# finance
# analyze
# models
# behavior
# operations
# detection
# market
# manufacturing
# fields
# sentiment
# activity
# optimization
# education
# disease
# diagnosis
# technologies
# clinical
# product
# used
# campaigns
# performance
# clustering
# classification
# patterns
# pattern
# categorizing
# mining
# data
# segmentation
# dataset
# regression
# behavior
# detection
# analysis
# applications
# trend
# clusters
# transactions
# categories
# detecting
# sequences
# analyzing
# techniques
# forecasting
# classes
# predicting
# recognition
# association
# rule
# things
# spam
# fraud
# predictive
# segments
# involves
# filtering
# modeling
# anomaly
# products
# maintenance
# distributed
# parallel
# computational
# computing
# processing
# processors
# computers
# computations
# processor
# computer
# scalability
# analytics
# performance
# datasets
# processes
# storage
# simultaneously
# distributing
# applications
# efficiently
# simulations
# machine
# learning
# network
# data
# scientific
# image
# processed
# complex
# reduce
# purpose
# handled
# resources
# smaller
# dividing
# video
# multiple
# involves
# main
# connected
# problems
# pieces
# handling
# power
# independently
# larger
# combined
# results
# solve
# assigned
# parallelism
# parallel
# processors
# concurrently
# computing
# processor
# programming
# distributed
# processing
# simultaneously
# openmp
# cores
# memory
# threads
# shared
# hybrid
# cache
# paradigms
# examples
# posix
# communicating
# paradigm
# pool
# models
# communicate
# dividing
# main
# parts
# share
# reduce
# accessing
# variables
# smaller
# messages
# using
# solve
# passing
# problems
# processing
# manage
# parallelism
# parallel
# abstractions
# encapsulation
# programming
# computing
# poop
# objects
# cores
# object
# paradigm
# oriented
# applications
# complexities
# code
# races
# development
# features
# complexity
# developers
# data
# main
# supports
# methods
# fields
# simplify
# reducing
# underlying
# parallelization
# parallelizing
# parallelized
# parallelize
# parallelism
# concurrently
# processors
# cores
# sequential
# pipeline
# tasks
# processor
# operations
# program
# task
# core
# combining
# hybrid
# performance
# operation
# chunks
# chunk
# processed
# independently
# involves
# functional
# overhead
# stages
# techniques
# dividing
# loops
# data
# advantage
# functions
# dependent
# technique
# combination
# subsets
# stage
# order
# loop
# combined
# performed
# results
# problems
# performance
# processors
# overhead
# parallel
# cores
# computing
# computations
# distributed
# communication
# costs
# sequential
# resources
# shared
# data
# significant
# scale
# executing
# required
# design
# load
# impact
# involves
# important
# distribute
# lot
# gains
# parallelize
# parallelism
# reduction
# parallel
# reduce
# reduces
# computing
# computations
# cores
# computation
# processors
# efficient
# efficiency
# distributed
# synchronization
# operation
# processor
# associative
# paradigm
# performance
# addition
# structure
# combining
# core
# contention
# advantages
# commutative
# combine
# communication
# overhead
# sums
# involves
# tree
# divided
# means
# array
# pairs
# combined
# sum
# improve
# subsets
# increase
# numbers
# caches
# cache
# memory
# processor
# performance
# multi
# architecture
# multiple
# computer
# slower
# hierarchy
# data
# l2
# l3
# purpose
# systems
# l1
# organized
# l4
# checks
# operation
# levels
# accessed
# speed
# pattern
# implement
# fastest
# larger
# proximity
# farther
# increases
# level
# fetched
# example
# consumption
# using
# use
# access
# reduces
# performance
# efficiency
# utilization
# parallel
# metrics
# computing
# metric
# measures
# calculated
# executing
# utilizing
# measured
# evaluating
# effectiveness
# systems
# utilized
# measure
# evaluate
# match
# security
# analyst
# analysts
# audits
# secure
# attacks
# safeguarding
# protecting
# threats
# analyze
# protect
# information
# ensuring
# assessments
# role
# organization
# data
# implement
# computer
# procedures
# develop
# latest
# measures
# technologies
# networks
# policies
# trends
# network
# effective
# test
# ensure
# sensitive
# systems
# potential
# main
# date
# stay
# perform
# leakage
# data
# breach
# viruses
# disclosure
# malware
# information
# disclose
# confidential
# malicious
# unauthorized
# software
# computer
# loss
# access
# transmission
# external
# transmit
# drives
# organizations
# network
# exposure
# networks
# systems
# caused
# divulging
# wep
# privacy
# wired
# phishing
# emails
# email
# passwords
# messages
# cyber
# theft
# attackers
# attacks
# antivirus
# attack
# sender
# cautious
# browsers
# text
# numbers
# protect
# legitimate
# wary
# use
# message
# browser
# card
# verify
# bank
# prevent
# confirm
# address
# electronic
# contact
# information
# computer
# software
# effective
# requests
# credit
# forms
# urgent
# trick
# anti
# trustworthy
# web
# detect
# vigilant
# usernames
# fake
# date
# organizations
# help
# check
# injection
# sql
# secure
# attacks
# protect
# validation
# validate
# queries
# inputs
# privileges
# implementing
# testing
# input
# ensure
# techniques
# privilege
# access
# data
# using
# parameterized
# handling
# practices
# accounts
# institutes
# code
# coding
# filter
# developing
# limit
# dynamic
# institute
# security
# confidentiality
# authorization
# unauthorized
# attacks
# integrity
# information
# access
# principles
# theory
# ensuring
# prevent
# concepts
# authorized
# governance
# systems
# data
# organization
# organizations
# roles
# establishing
# framework
# verifying
# granting
# users
# approach
# procedures
# managing
# aspects
# accessible
# effectiveness
# understanding
# identifying
# botnet
# botnets
# malware
# ddos
# attacks
# malicious
# security
# phishing
# attackers
# bot
# attacker
# computers
# infections
# infected
# antivirus
# compromised
# cryptocurrency
# spam
# mining
# computer
# threat
# passwords
# network
# login
# devices
# device
# protect
# automated
# scams
# emails
# use
# software
# using
# computing
# server
# accounts
# remotely
# traffic
# credentials
# flood
# zombie
# infect
# control
# websites
# users
# credential
# command
# generate
# operating
# systems
# xss
# attacks
# attacker
# javascript
# malicious
# stored
# attack
# persistent
# scripting
# web
# page
# executes
# reflected
# submitting
# injection
# server
# types
# input
# cross
# victim
# form
# occurs
# view
# example
# clicking
# target
# type
# code
# clicked
# site
# particularly
# number
# application
# detect
# website
# hand
# inject
# ucd
# design
# designers
# preferences
# centered
# users
# usable
# using
# iterative
# based
# needs
# create
# user
# important
# goals
# process
# incorporating
# ensures
# continue
# lead
# training
# helps
# involving
# means
# released
# reduce
# adopted
# usability
# testing
# satisfaction
# surveys
# evaluating
# survey
# using
# use
# conducted
# behavior
# users
# effective
# experience
# problems
# lab
# user
# observation
# observed
# asked
# goals
# conducting
# complete
# identify
# measure
# setting
# potential
# recorded
# make
# ensure
# including
# tasks
# task
# failures
# motivation
# failure
# computer
# approaches
# analyze
# interaction
# confidence
# fails
# approach
# using
# feedback
# evolving
# expectations
# use
# experiences
# ability
# frustrating
# interactions
# mistakes
# involve
# features
# game
# lack
# future
# attitude
# consider
# difficult
# culture
# reasons
# guidelines
# development
# practices
# requirements
# develop
# software
# standardized
# testing
# implementation
# maintenance
# design
# coding
# patterns
# release
# process
# manage
# production
# handling
# test
# reports
# issues
# feature
# variety
# feedback
# performance
# plan
# clearly
# hci
# interaction
# computer
# interface
# design
# framework
# designing
# frameworks
# performance
# implementation
# evaluation
# systems
# human
# components
# factors
# use
# process
# tasks
# product
# involves
# users
# create
# research
# specified
# prototyping
# incremental
# evolutionary
# discarded
# exercise
# case
# used
# design
# rationale
# creating
# activity
# determine
# life
# formed
# capture
# including
# doing
# way
# appropriate
# order
# option
# members
# provides
# evaluation
# evaluating
# evaluate
# methods
# evaluators
# techniques
# approaches
# method
# design
# objectives
# testing
# process
# development
# analysis
# inspection
# determine
# tasks
# characteristics
# effectiveness
# technique
# stages
# objective
# test
# expert
# equipment
# formal
# resources
# decisions
# factors
# feedback
# involves
# structured
# improvements
# using
# aspects
# qualitative
# methods
# research
# exploratory
# method
# procedures
# quantitative
# analyzing
# cognitive
# data
# formative
# evaluating
# learning
# hci
# empirical
# actions
# interaction
# involves
# development
# task
# feedback
# experiences
# action
# project
# quality
# results
# using
# participants
# model
# walkthrough
# stages
# accessibility
# evaluators
# goals
# wearable
# device
# accuracy
# reliable
# computer
# based
# ideas
# rigorous
# refine
# perspectives
# manually
# consistency
# goal
# evaluate
# learned
# usability
# qualitative
# quantitative
# methods
# empirical
# testing
# techniques
# research
# comparing
# method
# verbalize
# test
# procedures
# behavior
# experiences
# tasks
# data
# results
# design
# wearable
# compare
# task
# involves
# development
# participants
# protocol
# summative
# effective
# conducted
# using
# project
# actions
# accuracy
# discovery
# consistency
# evaluate
# observing
# various
# determine
# complete
# personas
# persona
# design
# designers
# diagrammatic
# clients
# models
# marketing
# stakeholders
# product
# narrative
# behavior
# strategic
# users
# structure
# multipurpose
# organizational
# effectiveness
# tasks
# development
# sophisticated
# products
# campaigns
# goals
# user
# tool
# developers
# sales
# build
# process
# communicate
# structures
# comes
# organization
# commitment
# digital
# tested
# doesn
# formative
# test
# understanding
# view
# planning
# understand
# plan
# powerful
# language
# business
# effort
# decisions
# designing
# designs
# design
# designers
# designer
# products
# product
# personas
# referential
# motivations
# users
# broad
# contexts
# self
# user
# model
# models
# issues
# extend
# accommodate
# development
# audience
# types
# variety
# mind
# satisfying
# create
# problems
# situations
# cases
# understand
# project
# target
# make
# causes
# range
# subsystems
# hierarchy
# subsystem
# systems
# requirements
# processes
# engineering
# components
# levels
# tasks
# models
# designing
# model
# process
# constraints
# complexity
# level
# technology
# parts
# consists
# organization
# development
# engineers
# comprehensive
# building
# factors
# detailed
# component
# define
# construct
# resource
# elements
# managing
# activities
# understanding
# development
# maintenance
# objectives
# requirements
# software
# managing
# projects
# deploying
# testing
# stakeholders
# stakeholder
# maintaining
# planning
# requirement
# model
# cycle
# validation
# process
# project
# life
# ensuring
# environment
# risks
# phases
# challenges
# stage
# risk
# goals
# design
# growth
# designing
# organizing
# necessities
# maintained
# budget
# defects
# process
# processes
# practice
# software
# requirements
# processes
# process
# engineering
# systems
# automate
# application
# hardware
# integrated
# maintenance
# deployment
# implementation
# technology
# designing
# computer
# design
# manufacturing
# components
# tasks
# structured
# lifecycle
# validation
# consists
# productivity
# objectives
# designed
# developing
# stages
# iterative
# analysis
# electronic
# inventory
# involves
# managing
# management
# project
# requires
# aerospace
# developed
# accounting
# integration
# verification
# industries
# developers
# waterfall
# development
# software
# requirements
# testing
# stages
# deployment
# process
# documentation
# defects
# model
# design
# projects
# acceptance
# tested
# maintenance
# architecture
# coded
# project
# components
# approach
# structured
# environment
# designs
# phases
# final
# changes
# tasks
# product
# deployed
# iteration
# developed
# progressed
# team
# completion
# needs
# requires
# structure
# issues
# lack
# hashing
# hash
# hashed
# linear
# buckets
# bucket
# stored
# data
# advantage
# table
# meaning
# array
# searching
# cuckoo
# space
# utilization
# elements
# element
# using
# key
# dynamic
# means
# store
# list
# fast
# searched
# additional
# determine
# access
# step
# grow
# main
# determined
# types
# used
# type
# hashing
# hash
# hashes
# hashed
# storage
# static
# stored
# algorithms
# search
# searches
# data
# memory
# store
# table
# items
# uses
# item
# locate
# retrieved
# maintenance
# operations
# defined
# positions
# value
# determine
# assigned
# position
# calculating
# remains
# process
# information
# set
# inserted
# tree
# trees
# databases
# nodes
# node
# searching
# searches
# insertions
# leaf
# structure
# pointers
# search
# structures
# advantages
# insertion
# balancing
# stored
# pointer
# index
# organizing
# disk
# data
# balanced
# faster
# organize
# deletions
# finding
# store
# matching
# systems
# root
# dynamic
# inserted
# utilization
# contains
# space
# arranged
# level
# deletion
# largest
# keys
# looking
# keeps
# time
# indexed
# index
# hash
# operations
# cost
# search
# operation
# scan
# hashed
# sequential
# access
# organizations
# file
# accessed
# structure
# depends
# locate
# record
# requires
# example
# required
# require
# desired
# affect
# indexing
# indexes
# hash
# index
# databases
# retrieval
# searching
# database
# storage
# lookup
# searches
# sorting
# storing
# compression
# tree
# data
# records
# huffman
# tables
# faster
# locate
# coding
# uses
# information
# table
# techniques
# quickly
# record
# disk
# structure
# memory
# advantage
# store
# fields
# using
# linking
# disadvantage
# field
# fast
# based
# node
# key
# points
# value
# values
# space
# operation
# ...
# legitimate
# campaigns
# send
# volumes
# emails
# promoting
# scams
# phishing
# stuffing
# automated
# websites
# attempting
# stolen
# login
# gain
# access
# accounts
# computing
# resources
# generate
# threat
# information
# security
# large-scale
# difficult
# detect
# disrupt
# preventative
# measures
# include
# keeping
# operating
# systems
# antivirus
# strong
# passwords
# protect
# xss
# attacker
# code
# malicious
# stored
# attack
# users
# reflected
# inject
# attacks
# victim
# delivered
# page
# type
# user
# website
# web
# types
# persistent
# non-persistent
# cross-site
# scripting
# main
# javascript
# application
# server
# visit
# target
# single
# injection
# comment
# section
# view
# hand
# input
# clicking
# submitting
# form
# order
# clicked
# executes
# considered
# detect
# ucd
# design
# systems
# user
# based
# users
# user-centered
# important
# ensures
# goals
# involving
# process
# incorporating
# create
# usable
# reduce
# training
# iterative
# designers
# continue
# released
# lead
# adopted
# system
# testing
# usability
# users
# conducted
# surveys
# evaluating
# goals
# including
# observation
# observed
# behavior
# recorded
# asked
# complete
# measure
# satisfaction
# experience
# lab
# setting
# conducting
# identify
# problems
# make
# ensure
# effective
# user
# user
# task
# system
# systems
# future
# fails
# complete
# failures
# lead
# tasks
# low
# expectations
# confidence
# decreases
# due
# reasons
# motivation
# interaction
# capture
# mistakes
# feedback
# perception
# negative
# failure
# approaches
# analyze
# involve
# influenced
# culture
# impact
# evolving
# features
# added
# initial
# computer
# game
# increase
# likelihood
# ability
# lack
# approach
# leading
# experiences
# repeated
# continue
# give
# altogether
# learning
# learn
# receive
# clear
# repeats
# perceive
# difficult
# frustrating
# attitude
# software
# standardized
# follow
# process
# develop
# test
# requirements
# design
# define
# clear
# development
# guidelines
# apply
# testing
# plan
# issues
# classified
# based
# activity
# life
# cycle
# activities
# gathering
# identify
# gather
# feedback
# patterns
# implementation
# coding
# control
# manage
# practices
# variety
# accounts
# production
# release
# maintenance
# handling
# reports
# feature
# making
# address
# performance
# system
# user
# design
# interaction
# computer
# hci
# framework
# systems
# users
# understand
# influence
# evaluation
# designing
# intuitive
# meet
# human-computer
# understanding
# components
# process
# involves
# research
# frameworks
# field
# fields
# study
# science
# related
# concerned
# implementation
# humans
# proposed
# product
# identifies
# interface
# performance
# easy
# refers
# factors
# user-centered
# conduct
# tasks
# test
# identify
# issues
# focusing
# discarded
# evolutionary
# incremental
# case
# prototyping
# design
# rationale
# formed
# activity
# creating
# life
# members
# capture
# order
# determine
# option
# evaluation
# design
# techniques
# choice
# stages
# involves
# methods
# process
# expert
# method
# influence
# identify
# factors
# analysis
# resources
# evaluators
# stage
# experts
# suggestions
# problems
# provide
# testing
# improvements
# evaluate
# equipment
# evaluating
# potential
# technique
# involve
# problem
# choosing
# objectives
# objective
# specific
# purpose
# determine
# development
# suited
# early
# quickly
# test
# concepts
# functioning
# availability
# time
# budget
# require
# specialized
# trained
# minimal
# characteristics
# field
# approaches
# include
# small
# group
# set
# principles
# working
# series
# tasks
# perspective
# typical
# identifying
# difficulties
# misunderstandings
# thought
# review
# relevant
# knowledge
# experience
# issues
# formal
# inspection
# structured
# established
# work
# human
# error
# heart
# depends
# variety
# data
# research
# methods
# formative
# qualitative
# quantitative
# method
# empirical
# user
# results
# involves
# cognitive
# story
# choose
# quality
# operators
# selection
# action
# goal
# goals
# consistency
# human-computer
# interaction
# hci
# earlier
# project
# evaluate
# refine
# ideas
# contribute
# development
# wearable
# device
# resulting
# walkthrough
# based
# theory
# exploratory
# learning
# manually
# simulating
# carrying
# stages
# model
# evaluators
# move
# task
# telling
# evaluating
# current
# accessibility
# correct
# control
# match
# label
# feedback
# goms
# analyzing
# learned
# good
# reliable
# valid
# unbiased
# accurately
# represent
# participants
# perspectives
# experiences
# collected
# rigorous
# standardized
# procedures
# ensure
# accuracy
# actions
# data
# research
# testing
# method
# summative
# qualitative
# empirical
# quantitative
# results
# methods
# users
# usability
# system
# determine
# involves
# version
# experiences
# consistency
# project
# test
# evaluate
# contribute
# development
# wearable
# device
# resulting
# observing
# identify
# issues
# conducted
# techniques
# think-aloud
# protocol
# verbalize
# thoughts
# actions
# co-discovery
# learning
# work
# complete
# discuss
# randomly
# assigning
# comparing
# behavior
# effective
# compare
# design
# placement
# scheme
# engagement
# good
# accurately
# represent
# participants
# perspectives
# collected
# rigorous
# standardized
# procedures
# ensure
# accuracy
# versions
# tasks
# task
# systems
# user
# design
# personas
# users
# common
# real
# product
# designers
# persona
# language
# test
# powerful
# process
# provide
# user
# tool
# problems
# development
# marketing
# products
# interest
# provides
# effort
# structures
# efforts
# structure
# multipurpose
# overcome
# plague
# digital
# determine
# behave
# goals
# tasks
# basis
# communicate
# stakeholders
# developers
# discussing
# decisions
# centered
# step
# build
# consensus
# commitment
# understanding
# reduce
# elaborate
# diagrammatic
# models
# found
# easier
# understand
# nuances
# behavior
# narrative
# employ
# measure
# effectiveness
# choices
# tested
# show
# formative
# doesn
# replace
# reality
# check
# solve
# iteration
# occur
# rapidly
# inexpensively
# whiteboard
# results
# stronger
# baseline
# time
# contribute
# product-related
# sales
# plan
# clients
# repurpose
# organization
# informing
# campaigns
# organizational
# strategic
# planning
# activities
# business
# units
# desire
# sophisticated
# knowledge
# typically
# view
# great
# design
# user
# product
# self-referential
# edge
# personas
# cases
# create
# audience
# products
# users
# satisfy
# accommodate
# broad
# designer
# make
# makes
# keeping
# mind
# variety
# types
# resolve
# user-centered
# issues
# arise
# development
# satisfying
# trouble
# applied
# problems
# contexts
# tool
# conceptions
# occurs
# project
# motivations
# models
# fall
# extend
# range
# apply
# understand
# works
# concur
# designing
# situations
# happen
# won
# target
# focus
# provide
# check
# goal
# goals
# designers
# designs
# system
# model
# components
# subsystems
# elements
# systems
# complex
# accurate
# subsystem
# models
# levels
# specific
# interactions
# create
# engineering
# consists
# restraining
# factors
# difficult
# hierarchy
# tasks
# requirements
# component
# level
# performs
# perform
# refers
# organization
# understanding
# designing
# managing
# typically
# representing
# purpose
# working
# achieve
# goal
# functions
# divided
# smaller
# building
# blocks
# parts
# define
# process
# activities
# steps
# processes
# essential
# functioning
# construct
# include
# complexity
# comprehensive
# lead
# details
# uncertainty
# development
# resource
# constraints
# limited
# time
# budget
# restrict
# develop
# life
# cycle
# project
# model
# software
# ensuring
# development
# requirements
# challenging
# testing
# managing
# quality
# resources
# risk
# phases
# stakeholders
# clear
# process
# time
# validation
# improvement
# maintenance
# estimating
# components
# projects
# resource
# risks
# meets
# meet
# phase
# essential
# approach
# planning
# designing
# maintaining
# necessities
# divides
# objectives
# organizing
# allocating
# budget
# identifying
# challenges
# stage
# ensures
# maintained
# incorporating
# verification
# goals
# progress
# issues
# complete
# growth
# lead
# delays
# process
# processes
# practice
# system
# systems
# engineering
# process
# requirements
# ensure
# computer-based
# meets
# expected
# performs
# deployment
# consists
# software
# designed
# transportation
# complex
# components
# developing
# involves
# design
# including
# end-users
# ensures
# perform
# stages
# stage
# safe
# computer
# technology
# tasks
# functions
# hardware
# data
# automate
# streamline
# processes
# improve
# efficiency
# enhance
# productivity
# found
# industries
# healthcare
# finance
# manufacturing
# include
# inventory
# management
# accounting
# electronic
# medical
# records
# structured
# approach
# designing
# managing
# application
# principles
# techniques
# typically
# analysis
# identified
# based
# implementation
# developed
# integration
# integrated
# work
# verification
# validation
# target
# made
# maintenance
# maintained
# address
# iterative
# continuous
# improvement
# lifecycle
# requires
# collaboration
# stakeholders
# developers
# testers
# project
# managers
# goals
# objectives
# essential
# aerospace
# software
# waterfall
# model
# testing
# phases
# requirements
# phase
# design
# project
# process
# team
# nature
# based
# deployment
# development
# product
# linear
# system
# end-users
# defects
# time-consuming
# documentation
# designs
# projects
# meets
# meet
# tasks
# distinct
# completed
# moving
# overlapping
# iteration
# gathers
# functional
# architecture
# including
# structure
# components
# relationships
# developed
# coded
# resulting
# working
# tested
# ensure
# performs
# expected
# includes
# unit
# integration
# user
# acceptance
# deployed
# target
# environment
# made
# maintenance
# maintained
# address
# updates
# enhancements
# structured
# approach
# applied
# makes
# difficult
# accommodate
# progressed
# occurs
# issues
# discovered
# stages
# fix
# lack
# limited
# result
# final
# overemphasis
# requires
# extensive
# hashing
# bucket
# linear
# elements
# element
# key
# determine
# hashed
# list
# store
# table
# hash
# main
# data
# type
# types
# dynamic
# grow
# works
# array
# inserted
# determined
# added
# end
# stored
# searching
# searched
# found
# checked
# advantage
# additional
# step
# making
# providing
# fast
# access
# times
# good
# space
# utilization
# buckets
# hash
# table
# data
# hashing
# static
# set
# search
# algorithms
# calculating
# makes
# memory
# position
# positions
# desired
# form
# storage
# store
# assigned
# remains
# deleted
# replaced
# fit
# works
# acts
# determine
# stored
# process
# hashed
# inserted
# retrieved
# locate
# time
# operations
# occur
# provide
# eliminates
# caused
# guessing
# information
# happen
# searches
# requires
# added
# removed
# hashes
# expected
# change
# changes
# tree
# node
# data
# pointers
# key
# item
# nodes
# trees
# root
# searches
# balanced
# self-balancing
# search
# reach
# insertion
# deletion
# structure
# keys
# pointer
# type
# dynamic
# index
# databases
# file
# systems
# store
# organize
# variation
# sorted
# advantages
# including
# space
# utilization
# faster
# disk
# arranged
# order
# smallest
# largest
# children
# makes
# inserted
# level
# located
# searching
# start
# stored
# find
# leaf
# matching
# present
# requires
# finding
# place
# based
# involves
# removing
# parts
# time
# times
# insertions
# deletions
# structures
# operations
# access
# cost
# indexed
# hashed
# file
# sequential
# record
# requires
# organizations
# depends
# required
# scan
# accessed
# search
# locate
# index
# hash
# structure
# operation
# require
# indexing
# based
# hash
# tree
# record
# data
# table
# lookup
# operation
# approach
# records
# type
# store
# specific
# performed
# main
# database
# location
# fast
# access
# searching
# node
# storage
# types
# times
# quickly
# locate
# index
# function
# applied
# resulting
# key
# points
# makes
# find
# advantage
# direct
# eliminates
# sorting
# large
# amounts
# structure
# works
# storing
# linking
# faster
# retrieval
# multiple
# searches
# disadvantage
# requires
# space
# indexes
# information
# including
# memory
# disk
# offset
# compression
# techniques
# huffman
# coding
# reduces
# requirements
# providing
# databases
# fields
# field
# tables
# remote
# data
# backup
# system
# storage
# off-site
# location
# access
# safe
# type
# backed
# pay
# case
# systems
# backups
# user
# secure
# typically
# stored
# fee
# physical
# drives
# part
# solution
# store
# businesses
# natural
# theft
# events
# works
# server
# encrypted
# process
# securely
# hardware
# damaged
# cost
# factors
# eliminates
# tape
# external
# hard
# unreliable
# additionally
# losing
# fire
# flood
# offer
# features
# wrong
# unauthorized
# manual
# intervention
# required
# ensures
# ensure
# users
# disasters
# disaster
# versions
# version
# storage
# primary
# memory
# secondary
# data
# computer
# files
# drives
# system
# stored
# ram
# information
# access
# records
# divided
# structure
# structures
# retrieval
# cpu
# provide
# main
# programs
# types
# organization
# categories
# working
# processed
# typically
# random
# chips
# fast
# quick
# modification
# power
# supply
# turned
# include
# hard
# hdds
# solid
# optical
# discs
# cds
# dvds
# tape
# recently
# cloud
# computing
# services
# amazon
# larger
# capacities
# offer
# slower
# times
# directly
# store
# fashion
# locate
# quickly
# provides
# disk
# disks
# levels
# data
# multiple
# organizations
# granularity
# detail
# breaking
# analyzing
# areas
# smaller
# components
# order
# patterns
# trends
# factors
# uncover
# gain
# deeper
# approach
# improvement
# specific
# insights
# concept
# sales
# product
# performance
# complex
# datasets
# decision-making
# customer
# board
# refers
# resolution
# involves
# granularities
# underlying
# company
# break
# category
# region
# store
# understand
# influencing
# increasingly
# important
# access
# larger
# drive
# understanding
# interact
# systems
# supply
# chains
# journeys
# identify
# operations
# drilling
# service
# development
# opportunities
# visible
# higher
# analysis
# additionally
# focus
# efforts
# address
# issues
# simultaneously
# limited
# resources
# invaluable
# tool
# gaining
# large
# optimizing
# organizational
# previously
# hidden
# lead
# improved
# increased
# efficiency
# insight
# locking
# validation-based
# distributed
# lock
# protocols
# protocol
# type
# maintain
# consistency
# databases
# work
# granted
# validation
# access
# time
# preventing
# conditions
# issues
# typically
# require
# granting
# ensures
# ensure
# transaction
# item
# timestamp
# data
# access
# order
# locked
# based
# released
# proceed
# lock
# operations
# locking
# protocols
# ensure
# time
# assigning
# unique
# determine
# assigned
# arrive
# system
# check
# checking
# earlier
# wait
# acquire
# locks
# locking
# protocol
# data
# two-phase
# transactions
# ensures
# locks
# phase
# preventing
# strict
# acquired
# control
# works
# requiring
# acquire
# read
# write
# release
# complete
# conflicts
# released
# operations
# completed
# occurring
# prevents
# ensuring
# items
# item
# lock
# operations
# data
# serializability
# reading
# reads
# order
# locks
# transactions
# conflicting
# executed
# preventing
# prevent
# ensure
# result
# results
# property
# database
# concurrent
# produces
# matter
# performed
# end
# important
# maintaining
# consistency
# race
# conditions
# achieved
# concurrently
# accessing
# time
# affecting
# addition
# providing
# rows
# inserted
# ensures
# property
# ensures
# database
# account
# transaction
# bank
# money
# completed
# multiple
# atomicity
# consistency
# isolation
# durability
# operations
# committed
# transfer
# users
# user
# acid
# stands
# set
# properties
# guarantee
# reliability
# successfully
# transferring
# data
# balance
# complete
# run
# concurrently
# affecting
# results
# update
# record
# time
# affect
# lost
# system
# failure
# power
# loss
# crashes
# committing
# made
# making
# remains
# remain
# multivalued
# dependencies
# dependency
# multiple
# dependent
# schema
# database
# refinement
# structure
# existing
# tables
# data
# performance
# adding
# process
# refine
# making
# model
# improve
# scalability
# security
# includes
# columns
# changing
# types
# indexes
# constraints
# modifying
# relationships
# modifications
# optimal
# refining
# removing
# redundant
# unnecessary
# elements
# important
# part
# design
# ensure
# optimized
# intended
# involves
# involve
# databases
# constraints
# accuracy
# data
# consistency
# integrity
# database
# foreign
# tables
# check
# enforce
# maintain
# complex
# referential
# key
# table
# related
# entered
# keys
# ensure
# sql
# involve
# attributes
# include
# type
# ensuring
# point
# valid
# primary
# maintaining
# matches
# enforcing
# specific
# conditions
# range
# allowed
# preventing
# special
# execute
# events
# inserting
# deleting
# rows
# business
# rules
# deletes
# ensures
# triggered
# table
# event
# trigger
# rows
# action
# triggering
# data
# occurs
# insert
# update
# triggers
# affected
# stored
# procedure
# database
# automatically
# consists
# parts
# condition
# delete
# operation
# executed
# include
# updating
# inserting
# defines
# inserted
# updated
# deleted
# statement
# affects
# number
# executes
# execute
# row
# clause
# group
# divide
# rows
# aggregate
# functions
# sum
# set
# conditions
# works
# operates
# grouped
# groups
# integrity
# constraint
# type
# table
# key
# ensures
# null
# tables
# ensure
# database
# primary
# foreign
# related
# check
# unique
# referential
# data
# rows
# types
# valid
# including
# set
# conditions
# met
# updated
# limit
# preventing
# updates
# database
# data
# system
# administrators
# performance
# application
# users
# user
# setting
# ensuring
# integrity
# monitoring
# dbas
# accounts
# access
# creating
# databases
# types
# interact
# transfer
# funds
# manage
# aspects
# storage
# security
# install
# maintain
# runs
# responsible
# managing
# maintaining
# including
# tables
# problems
# functions
# designing
# store
# efficiently
# permissions
# query
# issues
# implementing
# backups
# recovery
# plans
# needed
# maintenance
# activities
# reports
# assisting
# writing
# queries
# stored
# procedures
# dba
# account
# check
# checks
# raid
# storage
# performance
# data
# disks
# redundancy
# system
# multiple
# striping
# mirroring
# provides
# types
# levels
# redundant
# array
# independent
# technology
# combines
# single
# logical
# unit
# purpose
# providing
# reliability
# capacity
# improve
# implemented
# integrated
# common
# parity
# depending
# offers
# offer
# provide
# type
# level
# storage
# data
# stored
# information
# system
# lead
# failure
# power
# issue
# stores
# turned
# making
# storing
# variety
# loss
# stops
# working
# files
# result
# records
# relies
# entire
# boot
# related
# affects
# physical
# render
# costly
# repairs
# avoided
# measures
# place
# gains
# failed
# organizations
# rely
# operation
# operations
# failures
# fails
# fail
# lock
# locks
# type
# shared
# read
# held
# modifying
# accessing
# released
# acquire
# request
# acquired
# combines
# acquiring
# control
# access
# views
# procedures
# waiting
# causing
# blocked
# rolling
# back
# breaking
# involved

# %%
num_of_inputs = len(mod_ans_set)
sim_score = [0]*num_of_inputs
sbert_score = [0]*num_of_inputs
hf_score = [0] * num_of_inputs

# %%
def cos_sim(sent1_emb, sent2_emb):
  cos = np.dot(sent1_emb, sent2_emb)/(norm(sent1_emb)*norm(sent2_emb))
  return cos

def similarity_score(text1, text2, model):
  mod_sent = sent_tokenize(text1)
  usr_sent = sent_tokenize(text2)

  mod_emb = []
  usr_emb = []

  for sent in mod_sent:
    sent_emb = model.encode(sent)
    mod_emb.append(sent_emb)
  
  for sent in usr_sent:
    sent_emb = model.encode(sent)
    usr_emb.append(sent_emb)

  n = len(mod_sent)
  m = len(usr_sent)

  sim_ans = 0

  for i in range(0, n):
    for j in range(0, m):
      if(cos_sim(mod_emb[i], usr_emb[j]) >= 0.75):
        sim_ans += 1
        break
  
  sim_ans /= n
  return sim_ans

# %%
model = T5ForConditionalGeneration.from_pretrained('t5-small')
tokenizer = T5Tokenizer.from_pretrained('t5-small')
device = torch.device('cpu')

def summarize(text):
  preprocessed_text = text.strip().replace('\n', '')
  t5_input_text = 'summarize: ' + preprocessed_text

  tokenized_text = tokenizer.encode(t5_input_text, return_tensors='pt', max_length=512).to(device)

  summary_ids = model.generate(tokenized_text, min_length=30, max_length=120)
  summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)

  return summary

# %%
model_simcse = SentenceTransformer('princeton-nlp/sup-simcse-roberta-large')
model_crossencoder = CrossEncoder('cross-encoder/stsb-roberta-base')
model_sbert = SentenceTransformer('stsb-mpnet-base-v2')
model_hf = SentenceTransformer('sentence-transformers/paraphrase-xlm-r-multilingual-v1')
# Out:
# No sentence-transformers model found with name C:\Users\Raghav/.cache\torch\sentence_transformers\princeton-nlp_sup-simcse-roberta-large. Creating a new one with MEAN pooling.

# %%
for i in range(0, num_of_inputs):
    mod_ans = mod_ans_set[i]
    usr_ans = usr_ans_set[i]

    usr_ans += summarize(usr_ans)
    
    sim_val = similarity_score(mod_ans, usr_ans, model_simcse)
    sim_score[i] = sim_val
    sbert_val = similarity_score(mod_ans, usr_ans, model_sbert)
    sbert_score[i] = sbert_val
    hf_val = similarity_score(mod_ans, usr_ans, model_hf)
    hf_score[i] = hf_val
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.

# %%
simcse_score = sim_score
sbert_scoring = sbert_score
hf_score_normalized = hf_score
for i in range(0, num_of_inputs):
  simcse_score[i] = sim_score[i] * 10
  sbert_scoring[i] = sbert_scoring[i] * 10
  hf_score_normalized[i] = hf_score[i] * 10

# %%
simcse_score = np.array(simcse_score)
sbert_scoring = np.array(sbert_scoring)
hf_score_normalized = np.array(hf_score_normalized)

df['Sim_CSE Score'] = simcse_score.tolist()
df['SBERT Score'] = sbert_scoring.tolist()
df['HF_Score'] = hf_score_normalized.tolist()

# %%
nlp = en_core_web_trf.load()
n = df.shape[0]

df.insert(6,"Score_camembert", np.nan)
df.insert(7,"Score_NLTK", np.nan)
df.insert(8,"Score_spacy", np.nan)

# %%
def spacy_name(text):
  doc = nlp(text)
  named_entities = []
  for entity in doc.ents:
    named_entities.append((entity.text, entity.label_))
  return named_entities

def nltk_name(text):
  tokens = word_tokenize(text)
  pos_tags = pos_tag(tokens)
  final_pos1 =[]
  for i in pos_tags:
    if(i[1]=='NNP' or i[1]=='NNS' or i[1]=='NN'):
      final_pos1.append(i)
  named_entities = ne_chunk(final_pos1)
  leaves = named_entities.leaves()
  return leaves

def compute_score_nltk(a,b):
  user_arr = []
  modal_arr = []
    
  for i in range(0, len(a)):
    user_arr.append(a[i][0].lower())
  for i in range(0, len(b)):
    modal_arr.append(b[i][0].lower())
        
  entity_user = list(set(user_arr))
  entity_model = list(set(modal_arr))
    
  n = len(entity_model)
  n1 = len(entity_user)

  count = 0
  if(n==0):
    return 10
  for i in range(n):
    if(entity_model[i] in entity_user):
      count+=1
  count = (count/n)*10
  return count

def compute_score_spacy(user,modal):
  user_arr = []
  modal_arr = []
    
  for i in range(0, len(user)):
    if(user[i][1]!='CARDINAL'):
        user_arr.append(user[i][0].lower())
  for i in range(0, len(modal)):
    if(modal[i][1]!='CARDINAL'):
        modal_arr.append(modal[i][0].lower())
  user = list(set(user_arr))
  modal = list(set(modal_arr))
  
  n = len(modal)
  n1 = len(user)

  count = 0
  if(n==0):
    return 10
  for i in range(n):
    if(modal[i] in user):
      count+=1
  count = (count/n)*10
  return count

def regex(text):
  text2 = ''
  for i in text:
    if ((ord(i) >= 65 and ord(i) <= 90) or (ord(i) >= 97 and ord(i) <= 122) or ord(i)==32):
      text2+=i
  text2 = " ".join(text2.strip().split())
  text2 = text2.lower()
  return text2

# %%
tokenizer = AutoTokenizer.from_pretrained("Jean-Baptiste/camembert-ner")
model = AutoModelForTokenClassification.from_pretrained("Jean-Baptiste/camembert-ner")

def compute_score_camembert(modal, user):
    nlp = pipeline('ner', model=model, tokenizer=tokenizer, aggregation_strategy="simple")
    modal = nlp(modal)
    user = nlp(user)
    modal_arr = []
    user_arr = []
    for i in range(0, len(modal)):
        if(modal[i]['score']>=0.9):
            modal_arr.append(modal[i]['word'].lower())
    if(len(modal_arr)==0):
        return 10
    for i in range(0, len(user)):
        user_arr.append(user[i]['word'].lower())
    modal_arr = set(modal_arr)
    user_arr = set(user_arr)
    return (len(modal_arr.intersection(user_arr))/len(modal_arr))*10

# %%
for i in range(df.shape[0]):
  modal = df['Model Answer'][i]
  user = df['User Answer'][i]
  score_camembert = compute_score_camembert(modal, user)
  df['Score_camembert'][i] = score_camembert
  modal1 = regex(modal)
  user1 = regex(user)
  modal_entity_nltk = nltk_name(modal1)
  user_entity_nltk = nltk_name(user1)
  score_nltk = compute_score_nltk(user_entity_nltk,modal_entity_nltk)
  df['Score_NLTK'][i] = score_nltk
  modal_entity_spacy = spacy_name(modal)
  user_entity_spacy = spacy_name(user)
  score_spacy = compute_score_spacy(user_entity_spacy,modal_entity_spacy)
  df['Score_spacy'][i] = score_spacy
# Out:
# C:\Users\Raghav\AppData\Local\Temp\ipykernel_1152\1703605769.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Score_camembert'][i] = score_camembert
# C:\Users\Raghav\AppData\Local\Temp\ipykernel_1152\1703605769.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Score_NLTK'][i] = score_nltk
# C:\Users\Raghav\AppData\Local\Temp\ipykernel_1152\1703605769.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Score_spacy'][i] = score_spacy

# %%
df.to_csv(r'C:\Users\Raghav\Desktop\finalscores2.csv')
